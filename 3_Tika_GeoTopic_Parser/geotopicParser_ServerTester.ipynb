# %% [markdown]
# #### Run GeoTopic Parser End-to-End
# 1. Kill all java processes and kill tika server is already running (refer to Errors section fo ReadMe)
#     - `killall java`
#     - List current processes: `jps`
#         - Kill all tika processes with: `kill <process number>`
# 2. Navigate to directory /3_Tika_GeoTopic_Parser and run command to start lucene server: `lucene-geo-gazetteer -server`
# 3. In new terminal window, navigate to directory /3_Tika_GeoTopic_Parser and run command to start geotopic server: `./geotopic-server`
# 4. In new terminal window again, navigate to directory /3_Tika_GeoTopic_Parser and run command to test servers: `curl -T polar.geot -H "Content-Type: application/geotopic; filename=polar.geot" http://localhost:9998/rmeta | python -mjson.tool`
#     - Should Get if running correctly: `United States, 39.76, -98.5`

# %%
from tika import parser

# %%
# from tika import parser
# Parse the file with Tika and the GeoTopic Parser
parsed = parser.from_file('polar.geot', headers={'Content-Type' : 'application/geotopic'})
print(parsed)
# Out:
# {'metadata': {'Geographic_LONGITUDE': '-98.5', 'Geographic_NAME': 'United States', 'X-TIKA:Parsed-By-Full-Set': ['org.apache.tika.parser.DefaultParser', 'org.apache.tika.parser.geo.GeoParser'], 'resourceName': "b'polar.geot'", 'Optional_NAME1': 'People’s Republic of China', 'Optional_LATITUDE1': '35.0', 'Optional_LONGITUDE1': '105.0', 'X-TIKA:Parsed-By': ['org.apache.tika.parser.DefaultParser', 'org.apache.tika.parser.geo.GeoParser'], 'X-TIKA:parse_time_millis': '341', 'X-TIKA:embedded_depth': '0', 'Geographic_LATITUDE': '39.76', 'Content-Length': '881', 'Content-Type-Override': 'application/geotopic', 'Content-Type': 'application/geotopic'}, 'content': None, 'status': 200}

# %%
name = parsed['metadata']['Geographic_NAME']
latitude = parsed['metadata']['Geographic_LATITUDE']
longitude = parsed['metadata']['Geographic_LONGITUDE']

# %%
print(name)
print(latitude)
print(longitude)
# Out:
# United States
# 39.76
# -98.5

# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/Master_Dataset_GeoTopic.csv')

# %%
# set the width of the 'Narrative' column to 100 characters
pd.options.display.max_colwidth = 100

# %%
df.sample(20)[['Narrative', 'GeoTopic Name', 'GeoTopic Latitude', 'GeoTopic Longitude']]
# Out:
#                                                                                                  Narrative  \
# 10276  <p dir="ltr">देश के दूसरे CDS बनने पर पूर्व लेफ्टिनेंट जनरल श्री अनिल चौहान जी को हृदयतल से बधाई...
# 94450  Laal Singh Chaddha has recorded a low opening weekend in the vicinity of Rs 27 crore as the film...
# 63147  THE Shrine TOWN OF DEHU is gearing up to welcome Prime Minister Narendra Modi, who will dedicate...
# 37221                                                                                             Positive
# 72246                                                                                                 Food
# 79461                                                                                              Amazing
# 19192  I Am fortunate to be the President of Paralympic Committee of India at a time when I see the gro...
# 68590  <p dir="ltr">Carlos Alcaraz beats Casper Ruud in US Open final to win first grand slam at age of...
# 76535                                                                                      friends forever
# 26294  La supermodella con la carriera più longeva era presente domenica sera ai Bafta Awards accompagn...
# 70572                                                                                            Mussoorie
# 45582  The students of Bringston University are back for another school year. The CW announced today th...
# 87522                             <p dir="ltr">Music is take a skip from disasters in life...&#127911;</p>
# 34596  Stefanos Tsisipas è il primo finalista degli Internazionali d'Italia. Il tennista greco ha sconf...
# 30808  L'amichevole tra Olanda e Danimarca ha visto il ritorno in nazionale di Christian Eriksen dopo i...
# 56525                                                                    I fear missed calls from my mom🤐🤯
# 12222  <p dir="ltr">The famous Bandhani Saree of Gujarat ....</p>\n<p dir="ltr">The trending tie-dye ou...
# 66451  എന്റെ ഇന്നത്തെ ദിവസത്തിനു നിറം പകർന്ന മനുഷ്യൻ.... News 14 നു വേണ്ടി മേജൊ ജോസഫ് എന്ന വിഖ്യാതനായ മ...
# 32028                                                                                         #COMSPECTLBC
# 51925  — A set of twin British-era cannons each weighing 22-tonne, had been  found covered under mud in...
#
#                     GeoTopic Name  GeoTopic Latitude  GeoTopic Longitude
# 10276  People’s Republic of China              35.00               105.0
# 94450               United States              39.76               -98.5
# 63147  People’s Republic of China              35.00               105.0
# 37221  People’s Republic of China              35.00               105.0
# 72246               United States              39.76               -98.5
# 79461  People’s Republic of China              35.00               105.0
# 19192               United States              39.76               -98.5
# 68590  People’s Republic of China              35.00               105.0
# 76535               United States              39.76               -98.5
# 26294  People’s Republic of China              35.00               105.0
# 70572               United States              39.76               -98.5
# 45582  People’s Republic of China              35.00               105.0
# 87522  People’s Republic of China              35.00               105.0
# 34596  People’s Republic of China              35.00               105.0
# 30808               United States              39.76               -98.5
# 56525  People’s Republic of China              35.00               105.0
# 12222  People’s Republic of China              35.00               105.0
# 66451  People’s Republic of China              35.00               105.0
# 32028               United States              39.76               -98.5
# 51925               United States              39.76               -98.5
