# %%
import pandas as pd
import urllib.request
import os
import urllib.error

# %%
# Read the CSV file and create a DataFrame
df = pd.read_csv('../Datasets/Master_Dataset_Raw.csv')

# %%
# This line of code sets the maximum width of a column in a pandas DataFrame to be displayed without any truncation. 
pd.set_option('display.max_colwidth', None)

# Drop the duplicate URLs from the DataFrame
df = df.drop_duplicates(subset='Media')

# Define a lambda function to modify the URLs
modify_url = lambda url: url.replace(".com/", ".com/optimized/")

# Apply the lambda function to the "Media" column of the DataFrame
df['Media'] = df['Media'].apply(modify_url)

# %%
# extract column as a list
image_link_list = df['Media'].tolist()

# %%
start_index = 8726

for i in range(start_index, len(image_link_list), 1):

    url = image_link_list[i]

    print("Current Index:", i)

    try:
        urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
        print(f"Downloading image: {url}")
    except Exception as e:
        print(f"Error downloading image: {url} - {str(e)}")

    start_index = start_index + 1
# Out:
# Current Index: 8726
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16525108234468.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8727
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166262599674187.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8728
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164758867280078.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8729
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166485705658863.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8730
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165493662449909.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8731
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166278666470478.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8732
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164455018064671.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8733
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164256461967428.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8734
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165442058588602.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8735
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165045769369284.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8736
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165216628646454.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8737
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164402896062374.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8738
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166271130781389.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8739
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165268927752303.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8740
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166132884018966.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8741
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16649422735257.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8742
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166520966443527.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8743
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166555581442050.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8744
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164751230037225.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8745
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164466765459641.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8746
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165710342361967.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8747
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166161866319123.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8748
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166468847660377.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8749
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165614182688509.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8750
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16660075104603.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8751
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164402907936180.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8752
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166295356013982.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8753
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16646885282089.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8754
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165692212691841.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8755
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165623740588203.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8756
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165812701199263.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8757
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165554192356281.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8758
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166408652983798.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8759
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165312091719602.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8760
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164240245913675.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8761
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16520826343214.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8762
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165769494141836.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8763
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165778685866155.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8764
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165726567282487.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8765
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165053221416771.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8766
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165856802115210.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8767
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166183886828169.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8768
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165364178846926.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8769
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166337617247499.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8770
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166374272289207.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8771
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164940641358790.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8772
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166546036193513.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8773
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166462316183826.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8774
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165510649868957.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8775
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165045758990034.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8776
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166365387465991.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8777
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164905817062116.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8778
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166546281483040.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8779
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166176179682763.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8780
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166176171660732.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8781
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166331453760369.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8782
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166564420330850.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8783
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166438950094865.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8784
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16597115623685.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8785
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166054269178026.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8786
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165963583245818.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8787
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166063450881994.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8788
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166003875538414.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8789
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166016037032388.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8790
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166003889364884.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8791
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166111443552521.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8792
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166054252520157.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8793
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166063248632425.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8794
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-1660160626541.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8795
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165970953652439.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8796
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166065019340370.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8797
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166014919589292.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8798
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165970937535634.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8799
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166075623652727.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8800
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165971084983420.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8801
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166075585659093.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8802
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166029905243956.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8803
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166003856055736.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8804
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166029866492220.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8805
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166054289544838.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8806
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166014902451871.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8807
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16607569085429.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8808
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166003921859658.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8809
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166037885360383.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8810
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165971193963585.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8811
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165963550147829.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8812
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-1660378456341.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8813
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166083672827199.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8814
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166064959468595.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8815
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16594432681048.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8816
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165934440256010.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8817
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166092601586587.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8818
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165944138310843.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8819
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165944125512048.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8820
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165944109169882.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8821
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165934831117277.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8822
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166029536327529.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8823
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165952118070124.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8824
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166083133671049.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8825
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165952136395495.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8826
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165998323242963.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8827
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166092578625952.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8828
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166092511961655.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8829
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166023573815755.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8830
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165934497538959.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 8831
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16593619065136.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166438064318994.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10631
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16515733321610.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10632
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164623621098933.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10633
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165537491129052.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10634
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165738248242205.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10635
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165271855973729.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10636
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-16572802813954.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10637
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165347646944694.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10638
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164636482525266.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10639
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165596477990549.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10640
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165851166165349.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10641
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166481903179214.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10642
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166375263653840.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10643
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166601998180713.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10644
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165183423772218.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10645
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166248346340843.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10646
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165373554313513.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10647
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166420676067729.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10648
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165193710994514.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10649
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164420709433257.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10650
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166447005257315.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10651
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165607112150617.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10652
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164627317477931.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10653
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164627899998783.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10654
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166447220273227.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10655
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164017963394598.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10656
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164439052698970.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10657
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164874545739805.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10658
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164662817384017.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10659
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165580784097231.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10660
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166447088759065.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10661
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165624678398246.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10662
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166334350868892.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10663
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166170077977253.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10664
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165103723631119.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10665
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165103487312665.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10666
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165865105412551.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10667
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164793727177684.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10668
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164637406986969.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10669
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165737515199705.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10670
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164926275280746.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10671
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164977256721257.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10672
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-166188166646929.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10673
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-165683167261590.jpeg - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10674
# Error downloading image: https://image.pixstory.com/optimized/Pixstory-image-164684842622823.png - <urlopen error [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:1129)>
# Current Index: 10675
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/fn/pdhscw6s1wz7r1wk9ssprtz80000gn/T/ipykernel_3637/403235979.py in <module>
#       8
#       9     try:
# ---> 10         urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
#      11         print(f"Downloading image: {url}")
#      12     except Exception as e:
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     237     url_type, path = _splittype(url)
#     238
# --> 239     with contextlib.closing(urlopen(url, data)) as fp:
#     240         headers = fp.info()
#     241
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# ~/opt/anaconda3/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1344         try:
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#    1348             except OSError as err: # timeout error
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1283                 encode_chunked=False):
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#    1287     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1329             # default charset of iso-8859-1.
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#    1333     def getresponse(self):
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1278         else:
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#    1282     def request(self, method, url, body=None, headers={}, *,
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1038         msg = b"\r\n".join(self._buffer)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#    1042         if message_body is not None:
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in send(self, data)
#     978         if self.sock is None:
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#     982                 raise NotConnected()
#
# ~/opt/anaconda3/lib/python3.9/http/client.py in connect(self)
#    1452                 server_hostname = self.host
#    1453
# -> 1454             self.sock = self._context.wrap_socket(self.sock,
#    1455                                                   server_hostname=server_hostname)
#    1456
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # SSLSocket class handles server_hostname encoding before it calls
#     500         # ctx._wrap_socket()
# --> 501         return self.sslsocket_class._create(
#     502             sock=sock,
#     503             server_side=server_side,
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         # non-blocking
#    1040                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041                     self.do_handshake()
#    1042             except (OSError, ValueError):
#    1043                 self.close()
#
# ~/opt/anaconda3/lib/python3.9/ssl.py in do_handshake(self, block)
#    1308             if timeout == 0.0 and block:
#    1309                 self.settimeout(None)
# -> 1310             self._sslobj.do_handshake()
#    1311         finally:
#    1312             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
print(start_index)
