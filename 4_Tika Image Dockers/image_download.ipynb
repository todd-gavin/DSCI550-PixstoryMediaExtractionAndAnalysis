# %% [markdown]
# 7. Install Tika Image Dockers and generate captions for your Pixstory images posts
# - Download all 95k images associated with the posts ...Write a simple python script to do this
# - Install Tika Dockers package for Image Captioning and Object Recognition
# - DONE - git clone https://github.com/USCDataScience/tika-dockers.git and https://hub.docker.com/r/uscdatascience/im2txt-rest-tika
# - Read and test out: https://cwiki.apache.org/confluence/display/TIKA/TikaAndVisionDL4J iii.
# - Read and test out: https://github.com/apache/tika/pull/189
# - Iterate through all the Pixstory posts and add the generated image caption and the detect object(s) column to your dataset

# %%
import pandas as pd
import urllib.request
import os
import urllib.error

#path to raw data set = "../Datasets/Master_Dataset_Raw.csv"

# %% [markdown]
# # Creating a function that downloads the images - Ran into error

# %%
# Read the CSV file and create a DataFrame
df = pd.read_csv('../Datasets/Master_Dataset_Raw.csv')

pd.set_option('display.max_colwidth', None)

# Define a lambda function to modify the URLs
modify_url = lambda url: url.replace(".com/", ".com/optimized/")

# Apply the lambda function to the "Media" column of the DataFrame
df['Media'] = df['Media'].apply(modify_url)

# Define a lambda function to download each image
download_image = lambda url: urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")

# Apply the lambda function to each element in the "Media" column
df['Media'].apply(download_image)

#stopped working at 1705 files
#Problematic image: "https://image.pixstory.com/optimized/Pixstory-image-1605712733.jpg" this isn't opening an image
#this image is contained in the following rows: 8,9,33,36 

df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/daniilabbruzzese/Documents/Senior Year/DSCI 550/assignment 2/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika Image Dockers/image_download.ipynb Cell 4 in <cell line: 16>()
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> download_image = lambda url: urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> # Apply the lambda function to each element in the "Media" column
# ---> <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> df['Media'].apply(download_image)
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a> #stopped working at 1705 files
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a> #Problematic image: "https://image.pixstory.com/optimized/Pixstory-image-1605712733.jpg" this isn't opening an image
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> #this image is contained in the following rows: 8,9,33,36
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=21'>22</a> df
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# /Users/daniilabbruzzese/Documents/Senior Year/DSCI 550/assignment 2/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika Image Dockers/image_download.ipynb Cell 4 in <lambda>(url)
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> df['Media'] = df['Media'].apply(modify_url)
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> # Define a lambda function to download each image
# ---> <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> download_image = lambda url: urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=14'>15</a> # Apply the lambda function to each element in the "Media" column
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/image_download.ipynb#W3sZmlsZQ%3D%3D?line=15'>16</a> df['Media'].apply(download_image)
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
#     243     # URLs. No sense in performing a copy unless requested.
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:1346, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344 try:
#    1345     try:
# -> 1346         h.request(req.get_method(), req.selector, req.data, headers,
#    1347                   encode_chunked=req.has_header('Transfer-encoding'))
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 def request(self, method, url, body=None, headers={}, *,
#    1283             encode_chunked=False):
#    1284     """Send a complete request to the server."""
# -> 1285     self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327 if isinstance(body, str):
#    1328     # RFC 2616 Section 3.7.1 says that text default has a
#    1329     # default charset of iso-8859-1.
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1278 else:
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1038 msg = b"\r\n".join(self._buffer)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#    1045     if hasattr(message_body, 'read'):
#    1046         # Let file-like take precedence over byte-like.  This
#    1047         # is needed to allow the current position of mmap'ed
#    1048         # files to be taken into account.
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:980, in HTTPConnection.send(self, data)
#     978 if self.sock is None:
#     979     if self.auto_open:
# --> 980         self.connect()
#     981     else:
#     982         raise NotConnected()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1454, in HTTPSConnection.connect(self)
#    1451 else:
#    1452     server_hostname = self.host
# -> 1454 self.sock = self._context.wrap_socket(self.sock,
#    1455                                       server_hostname=server_hostname)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:500, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     494 def wrap_socket(self, sock, server_side=False,
#     495                 do_handshake_on_connect=True,
#     496                 suppress_ragged_eofs=True,
#     497                 server_hostname=None, session=None):
#     498     # SSLSocket class handles server_hostname encoding before it calls
#     499     # ctx._wrap_socket()
# --> 500     return self.sslsocket_class._create(
#     501         sock=sock,
#     502         server_side=server_side,
#     503         do_handshake_on_connect=do_handshake_on_connect,
#     504         suppress_ragged_eofs=suppress_ragged_eofs,
#     505         server_hostname=server_hostname,
#     506         context=self,
#     507         session=session
#     508     )
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1040, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1037         if timeout == 0.0:
#    1038             # non-blocking
#    1039             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040         self.do_handshake()
#    1041 except (OSError, ValueError):
#    1042     self.close()
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1309, in SSLSocket.do_handshake(self, block)
#    1307     if timeout == 0.0 and block:
#    1308         self.settimeout(None)
# -> 1309     self._sslobj.do_handshake()
#    1310 finally:
#    1311     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('../Datasets/Master_Dataset_Raw.csv')

df
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID  \
# 0                121169  STY1659426957              103  USR1606807023
# 1                127727  STY1660634861              103  USR1606807023
# 2                123665  STY1660027898              103  USR1606807023
# 3                130517  STY1661151635              103  USR1606807023
# 4                125466  STY1660372361              109  USR1606851217
# ...                 ...            ...              ...            ...
# 94995            125349  STY1660325841            71665  USR1660325291
# 94996            125345  STY1660325638            71673  USR1660325486
# 94997            125355  STY1660326971            71697  USR1660326022
# 94998            125351  STY1660326276            71698  USR1660326026
# 94999            125354  STY1660326403            71708  USR1660326251
#
#        Gender  Age                                             Title  \
# 0      female   34                     Trend of the Year: Barbiecore
# 1      female   34                            Abomination of the day
# 2      female   34                         Shameful headline in 2022
# 3      female   34  Woman lawyer arrested for abusing security guard
# 4      others   31              What is the Inflation Reduction Act?
# ...       ...  ...                                               ...
# 94995     NaN   18                                      COLLEGE LIFE
# 94996     NaN   17                          The one with the bestie😍
# 94997     NaN   19                                           College
# 94998     NaN   21                              A tale of friendship
# 94999     NaN   17                       The mandatory mirror selfie
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Narrative  \
# 0      The colour of the year is here, and it's *drumroll*…hot pink. Barbiecore - Mattel's Barbie doll aesthetic - has been seen on everything and everyone from Kim K to Megan Fox to Rosalía to Margot Robbie (who stars in the upcoming Barbie movie directed by Greta Gerwig). \n\nThe signature shade of shocking pink has been featured in every fashion line - from the Versace Medusa Aevitas heels to Nensi Dojaka's cutout bodycon dresses. \n\nAccording to Klarna, data shows that search results for pink items have seen an increase in purchases. Pink mini dresses have seen an 970% increase and pink swimsuits have seen a 682% increase in the past six months. \n\nIt may be a little divisive if you’re not a pink lover, but after the last few grim years, this cheerful candy aesthetic might be just what you need to enliven your day. \n\nIf you're intimidated by the colour pink, start small: cherry-tinted sunglasses or headbands; a fuchsia clutch; or a magenta bodysuit under a blazer will all be the perfect entryway to all things Barbie.\n\nSo, how do you feel about this one? A hit or a miss for you?
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      We Indians do love to bastardise our foods- Chinese bhel, chopsuey, Szechuan noodles- all these would scandalise a Chinese person, who would not recognise their home food in our aggressively spicy dishes! \n\nI don’t mind it, to be honest. ‘Chinjabi’ food deserves its own recognition! But I have to draw the line at ‘tutti frutti momos’ and ‘momo burgers’ and momo pizza. WHY on earth would you ever put a momo inside a burger? Those textures do not play well at all together 😭 it just doesn’t make sense \n\nWhat’s the weirdest fusion food you’ve ever seen on a menu?
#
#                                                                                                                                         Interest
# 0                                                                                                                        trends, fashion, barbie
# 1                                                                                                                       Food, momos, weird menus
# 2                                                                                                                          misogyny, st  xaviers
# 3      Technology, History, Food, Entertainment, Sports, Environment, Science, Education, Health, Politics, Economy, Climate change , harassment
# 4                                                                                                                                  us government
# ...                                                                                                                                          ...
# 94995                                                                                                           college life, college life umang
# 94996                                                                                                                               college life
# 94997                                                                                                           college life, college life umang
# 94998                                                                                                                                    friends
# 94999                                                                                                                               college life
#
# [95000 rows x 12 columns]

# %% [markdown]
# # Identifying Rows in the DF given the URL

# %%
#check how many files in a folder: 
#cd /Users/daniilabbruzzese/Documents/Senior\ Year/DSCI\ 550/assignment\ 2/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika\ Image\ Dockers/95k_Images
#ls -1 | wc -l



row_1705 = df.iloc[1703]


df.loc[df['Media'] == 'https://image.pixstory.com/optimized/Pixstory-image-1659450906604.png']
# Out:
#     Story Primary ID       Story ID  User Primary ID        User ID  Gender  \
# 8             121828  STY1659554880                2  USR1605614195  others
# 9             121349  STY1659450917                2  USR1605614195  others
# 33            121828  STY1659554880                2  USR1605614195  others
# 36            121349  STY1659450917                2  USR1605614195  others
#
#     Age                                Title  \
# 8    27                         Hi, whats up
# 9    27  You can never go wrong with Led Zep
# 33   27                         Hi, whats up
# 36   27  You can never go wrong with Led Zep
#
#                                                              Narrative  \
# 8                                        <p dir="ltr">Hi, whats up</p>
# 9   <p dir="ltr">You can never go wrong with <b>Led</b> <b>Zep</b></p>
# 33                                       <p dir="ltr">Hi, whats up</p>
# 36  <p dir="ltr">You can never go wrong with <b>Led</b> <b>Zep</b></p>
#
#                                                                     Media  \
# 8   https://image.pixstory.com/optimized/Pixstory-image-1659450906604.png
# 9   https://image.pixstory.com/optimized/Pixstory-image-1659450906604.png
# 33  https://image.pixstory.com/optimized/Pixstory-image-1659450906604.png
# 36  https://image.pixstory.com/optimized/Pixstory-image-1659450906604.png
#
#    Account Created Date Date (No Timestamp)  \
# 8   2020-11-17 17:26:00          2020-11-17
# 9   2020-11-17 17:26:00          2020-11-17
# 33  2020-11-17 17:26:35          2020-11-17
# 36  2020-11-17 17:26:35          2020-11-17
#
#                                                                                                                                      Interest
# 8   Technology, History, Food, Entertainment, Sports, Environment, Science, Inequality, Education, Health, Politics, Economy, Climate change
# 9   Technology, History, Food, Entertainment, Sports, Environment, Science, Inequality, Education, Health, Politics, Economy, Climate change
# 33  Technology, History, Food, Entertainment, Sports, Environment, Science, Inequality, Education, Health, Politics, Economy, Climate change
# 36  Technology, History, Food, Entertainment, Sports, Environment, Science, Inequality, Education, Health, Politics, Economy, Climate change

# %% [markdown]
# # Downloading the Images, and printing each URL as it downloads

# %%
# Read the CSV file and create a DataFrame
df = pd.read_csv('../Datasets/Master_Dataset_Raw.csv')

pd.set_option('display.max_colwidth', None)

# Define a lambda function to modify the URLs
modify_url = lambda url: url.replace(".com/", ".com/optimized/")

# Apply the lambda function to the "Media" column of the DataFrame
df['Media'] = df['Media'].apply(modify_url)


# Define a lambda function to download each image and print the URL
def download_image(url):
    print(f"Downloading image: {url}")
    urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")

# Apply the lambda function to each element in the "Media" column
df['Media'].apply(download_image)
# Out:
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165942680078373.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166063451420678.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166002765039504.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166115086348280.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166037194433431.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164795793635265.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-163475628980648.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166014602617069.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-1659450906604.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-1659450906604.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165945052392562.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165295246456038.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165129496980335.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-163475628980648.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165306282095491.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166014602617069.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165295384274628.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166594154245949.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166280116034822.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165235268663239.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166192146575433.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165044443861699.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165306282095491.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164795793635265.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-162153257364412.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164795793635265.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164796603181668.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164797028861723.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165275158198954.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166014602617069.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166295584219304.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165329722615496.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166280219689214.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-1659450906604.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-
jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165191979831482.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-163938713185050.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164443055434876.jpeg
# ...
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16502915054352.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164674366215794.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16629982429584.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165780090884089.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16509158112037.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16494165419412.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165723060581552.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165685702612136.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164674359857774.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165841026740894.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16643954059437.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166368795149477.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166506164774545.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166450823461439.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166569676575273.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166005590073685.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166423948452718.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16649131144015.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164649903459906.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166206232592764.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166195870331703.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165842600123499.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166377722050949.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166031141217078.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16618917956045.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166251732653776.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166007725820772.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165827138749209.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164649903459906.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165914631828031.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16509158112037.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164649903459906.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164804129527149.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166195870331703.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166130680144373.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164389524724823.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166130680144373.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166333621922343.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166033013838019.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166423962397306.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166195870331703.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165905142633986.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16637890243544.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165850364680244.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165999101669471.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166458291934489.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166458304831453.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165713165213212.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166558084338872.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166343153527854.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164812705796014.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166000321436688.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16624323175113.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166073990472366.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166073990472366.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166551097616522.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166387202661903.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166014369678480.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166303349551372.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166445227167743.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166241314425448.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166187516640392.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16637107727913.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166025605821512.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166325430594113.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165823238994114.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166022936098906.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166551486294856.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166511039139249.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166325179942996.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166578390995302.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166514707264813.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166428145817739.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-1662918329993.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16590171597992.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165996613590354.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166204637661275.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-1659835119696.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166558084338872.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164751921178033.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165911528587431.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165771477012019.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16619971812140.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166325179942996.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164649903459906.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-16643849273967.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166016305420055.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165114892261172.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164415252379582.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164370292854565.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164294546737251.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164816662645370.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-164492494955002.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166255629274448.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165104602098811.jpeg
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166080851587825.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166073057331.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166073387558542.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166115686416081.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166115704470723.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166080488341797.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166062053941110.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166091639219596.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-166019302094412.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-165363974714692.png
# Downloading image: https://image.pixstory.com/optimized/Pixstory-image-1605712733.jpg
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /Users/daniilabbruzzese/Documents/Senior Year/DSCI 550/assignment 2/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika Image Dockers/images.ipynb Cell 5 in <cell line: 19>()
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>     urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> # Apply the lambda function to each element in the "Media" column
# ---> <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W5sZmlsZQ%3D%3D?line=18'>19</a> df['Media'].apply(download_image)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# /Users/daniilabbruzzese/Documents/Senior Year/DSCI 550/assignment 2/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika Image Dockers/images.ipynb Cell 5 in download_image(url)
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a> def download_image(url):
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a>     print(f"Downloading image: {url}")
# ---> <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>     urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
#     243     # URLs. No sense in performing a copy unless requested.
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 403: Forbidden

# %% [markdown]
# # Downloading Each Image, skipping images that have an error and recording the erros in a txt file

# %%
# Read the CSV file and create a DataFrame
df = pd.read_csv('../Datasets/Master_Dataset_Raw.csv')

pd.set_option('display.max_colwidth', None)

# Define a lambda function to modify the URLs
modify_url = lambda url: url.replace(".com/", ".com/optimized/")

# Apply the lambda function to the "Media" column of the DataFrame
df['Media'] = df['Media'].apply(modify_url)

# Define a lambda function to download each image and log any errors
def download_image(url):
    try:
        urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
    except Exception as e:
        with open("download_errors.txt", "a") as f:
            f.write(f"Error downloading image: {url} - {e}\n")

# Apply the lambda function to each element in the "Media" column
df['Media'].apply(download_image)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/daniilabbruzzese/Documents/Senior Year/DSCI 550/assignment 2/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika Image Dockers/images.ipynb Cell 10 in <cell line: 21>()
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W6sZmlsZQ%3D%3D?line=17'>18</a>             f.write(f"Error downloading image: {url} - {e}\n")
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W6sZmlsZQ%3D%3D?line=19'>20</a> # Apply the lambda function to each element in the "Media" column
# ---> <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W6sZmlsZQ%3D%3D?line=20'>21</a> df['Media'].apply(download_image)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1082, in SeriesApply.apply(self)
#    1078 if isinstance(self.f, str):
#    1079     # if we are a string, try to dispatch
#    1080     return self.apply_str()
# -> 1082 return self.apply_standard()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py:1137, in SeriesApply.apply_standard(self)
#    1131         values = obj.astype(object)._values
#    1132         # error: Argument 2 to "map_infer" has incompatible type
#    1133         # "Union[Callable[..., Any], str, List[Union[Callable[..., Any], str]],
#    1134         # Dict[Hashable, Union[Union[Callable[..., Any], str],
#    1135         # List[Union[Callable[..., Any], str]]]]]"; expected
#    1136         # "Callable[[Any], Any]"
# -> 1137         mapped = lib.map_infer(
#    1138             values,
#    1139             f,  # type: ignore[arg-type]
#    1140             convert=self.convert_dtype,
#    1141         )
#    1143 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1144     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1145     #  See also GH#25959 regarding EA support
#    1146     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx:2870, in pandas._libs.lib.map_infer()
#
# /Users/daniilabbruzzese/Documents/Senior Year/DSCI 550/assignment 2/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika Image Dockers/images.ipynb Cell 10 in download_image(url)
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a> def download_image(url):
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a>     try:
# ---> <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a>         urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W6sZmlsZQ%3D%3D?line=15'>16</a>     except Exception as e:
#      <a href='vscode-notebook-cell:/Users/daniilabbruzzese/Documents/Senior%20Year/DSCI%20550/assignment%202/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika%20Image%20Dockers/images.ipynb#W6sZmlsZQ%3D%3D?line=16'>17</a>         with open("download_errors.txt", "a") as f:
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
#     243     # URLs. No sense in performing a copy unless requested.
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:517, in OpenerDirector.open(self, fullurl, data, timeout)
#     514     req = meth(req)
#     516 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517 response = self._open(req, data)
#     519 # post-process response
#     520 meth_name = protocol+"_response"
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:534, in OpenerDirector._open(self, req, data)
#     531     return result
#     533 protocol = req.type
# --> 534 result = self._call_chain(self.handle_open, protocol, protocol +
#     535                           '_open', req)
#     536 if result:
#     537     return result
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:1389, in HTTPSHandler.https_open(self, req)
#    1388 def https_open(self, req):
# -> 1389     return self.do_open(http.client.HTTPSConnection, req,
#    1390         context=self._context, check_hostname=self._check_hostname)
#
# File ~/opt/anaconda3/lib/python3.9/urllib/request.py:1350, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348     except OSError as err: # timeout error
#    1349         raise URLError(err)
# -> 1350     r = h.getresponse()
#    1351 except:
#    1352     h.close()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Downloading images such that I can start where I left off at the last index

# %%
# Read the CSV file and create a DataFrame
df = pd.read_csv('../Datasets/Master_Dataset_Raw.csv')

pd.set_option('display.max_colwidth', None)

# Drop the duplicate URLs from the DataFrame
df = df.drop_duplicates(subset='Media')

# Define a lambda function to modify the URLs
modify_url = lambda url: url.replace(".com/", ".com/optimized/")

# Apply the lambda function to the "Media" column of the DataFrame
df['Media'] = df['Media'].apply(modify_url)

# Set the starting index for resuming the download
start_index = 8726

# Define a lambda function to download each image and print the URL
def download_image(url):
    global start_index
    index = df[df['Media'] == url].index[0]
    if index < start_index:
        print(f"Skipping image: {url}")
        return
    print(f"Downloading image: {url}")
    try:
        urllib.request.urlretrieve(url, f"95k_Images/{url.split('/')[-1]}")
    except Exception as e:
        print(f"Error downloading image: {url} - {str(e)}")
        return
    start_index = index + 1

# Apply the lambda function to each element in the "Media" column
df['Media'].apply(download_image)

# %%
# check if the index of the non-ordered DataFrame is ordered correctly
print(df.index.is_monotonic_increasing)

#check how many files in a folder: 
#cd /Users/daniilabbruzzese/Documents/Senior\ Year/DSCI\ 550/assignment\ 2/DSCI550-PixstoryMediaExtractionAndAnalysis/4_Tika\ Image\ Dockers/95k_Images
#ls -1 | wc -l
# Out:
# True
# False
# True

# %%
# Check the number of unique URLs in the "Media" column
num_unique_urls = df['Media'].nunique()

# Check the total number of rows in the DataFrame
num_rows = len(df)

# Print the results
print(f"Number of unique URLs: {num_unique_urls}")
print(f"Total number of rows: {num_rows}")
# Out:
# Number of unique URLs: 80585
# Total number of rows: 80585
