# %%
import pandas as pd
from bs4 import BeautifulSoup
import os

# %%
# df_master_dataset = pd.read_csv('Master_Dataset.tsv', delimiter='\t')
df_master_dataset = pd.read_csv('Master_Dataset_Detoxified_Complete.csv')

# %%
df_master_dataset.head(20)
# Out:
#     Unnamed: 0  Story Primary ID       Story ID  User Primary ID  \
# 0            0            121169  STY1659426957              103
# 1            1            127727  STY1660634861              103
# 2            2            123665  STY1660027898              103
# 3            3            130517  STY1661151635              103
# 4            4            125466  STY1660372361              109
# 5            5            129472  STY1660912862                2
# 6            6            128902  STY1660827749                2
# 7            7            124381  STY1660146053                2
# 8            8            121828  STY1659554880                2
# 9            9            121349  STY1659450917                2
# 10          10            121347  STY1659450529                2
# 11          11            101194  STY1652952597                2
# 12          12             97563  STY1651295583                2
# ...

# %%
# reset the index and drop the old index column
# df_master_dataset = df_master_dataset.reset_index(drop=True)

# %%
# A function to extract the text from an Narrative HTML string
def extract_text(html):
    try: 
        soup = BeautifulSoup(html, 'html.parser')
        text = soup.get_text()
    except:
        text = html
    # print(text)
    return text

# %%
# Apply the function to each row of the DataFrame and create a new column with the result
df_master_dataset['Narrative'] = df_master_dataset['Narrative'].apply(extract_text)
# Out:
# /Users/toddgavin/opt/anaconda3/lib/python3.9/site-packages/bs4/__init__.py:404: MarkupResemblesLocatorWarning: The input looks more like a URL than markup. You may want to use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(
# /Users/toddgavin/opt/anaconda3/lib/python3.9/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
df_master_dataset.head(20)
# Out:
#     Unnamed: 0  Story Primary ID       Story ID  User Primary ID  \
# 0            0            121169  STY1659426957              103
# 1            1            127727  STY1660634861              103
# 2            2            123665  STY1660027898              103
# 3            3            130517  STY1661151635              103
# 4            4            125466  STY1660372361              109
# 5            5            129472  STY1660912862                2
# 6            6            128902  STY1660827749                2
# 7            7            124381  STY1660146053                2
# 8            8            121828  STY1659554880                2
# 9            9            121349  STY1659450917                2
# 10          10            121347  STY1659450529                2
# 11          11            101194  STY1652952597                2
# 12          12             97563  STY1651295583                2
# ...

# %%
# write the DataFrame to a TSV file
# df_master_dataset.to_csv('Master_Dataset.tsv', sep='\t', index=False)
df_master_dataset.to_csv('Master_Dataset_Detoxified_Complete.csv', index=False)
