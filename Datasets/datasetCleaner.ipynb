# %%
import pandas as pd

# %%
df = pd.read_csv('Master_Dataset_TranslationsDetoxifyGeoTopicImages_Complete.csv')
# Out:
# /var/folders/fn/pdhscw6s1wz7r1wk9ssprtz80000gn/T/ipykernel_26153/3937608625.py:1: DtypeWarning: Columns (2,3,5,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Master_Dataset_TranslationsDetoxifyGeoTopicImages_Complete.csv')

# %%
df.sample(20)
# Out:
#                                                    Media  \
# 72097  https://image.pixstory.com/Pixstory-image-1656...
# 87885  https://image.pixstory.com/Pixstory-image-1662...
# 77482  https://image.pixstory.com/Pixstory-image-1664...
# 85559  https://image.pixstory.com/Pixstory-image-1661...
# 82306  https://image.pixstory.com/Pixstory-image-1660...
# 84652  https://image.pixstory.com/Pixstory-image-1661...
# 1645   https://image.pixstory.com/Pixstory-image-1657...
# 86172  https://image.pixstory.com/Pixstory-image-1661...
# 11453  https://image.pixstory.com/Pixstory-image-1645...
# 62167  https://image.pixstory.com/Pixstory-image-1651...
# 9335   https://image.pixstory.com/Pixstory-image-1664...
# 63907  https://image.pixstory.com/Pixstory-image-1654...
# 5778   https://image.pixstory.com/Pixstory-image-1649...
# 39612  https://image.pixstory.com/Pixstory-image-1649...
# 39518  https://image.pixstory.com/Pixstory-image-1651...
# ...

# %%
df.columns
# Out:
# Index(['Media', 'object_recognition', 'Unnamed: 0', 'Story Primary ID',
#        'Story ID', 'User Primary ID', 'User ID', 'Gender', 'Age', 'Title',
#        'Narrative', 'Account Created Date', 'Date (No Timestamp)', 'Interest',
#        'Narrative TikaDetect', 'Title TikaDetect', 'Narrative LangDetect',
#        'Title LangDetect', 'Translated Narrative', 'Translated Title',
#        'toxicity', 'severe_toxicity', 'obscene', 'identity_attack', 'insult',
#        'threat', 'sexual_explicit', 'GeoTopic Name', 'GeoTopic Latitude',
#        'GeoTopic Longitude', 'caption'],
#       dtype='object')

# %%
# rename the columns
df = df.rename(columns={'Unnamed: 0': 'Dataset Index', 'caption': 'caption_generation'})

# %%
df.sample(20)
# Out:
#                                                    Media  \
# 42155  https://image.pixstory.com/Pixstory-image-1642...
# 22938  https://image.pixstory.com/Pixstory-image-1645...
# 1190   https://image.pixstory.com/Pixstory-image-1662...
# 89406  https://image.pixstory.com/Pixstory-image-1662...
# 45585  https://image.pixstory.com/Pixstory-image-1659...
# 41117  https://image.pixstory.com/Pixstory-image-1642...
# 78672  https://image.pixstory.com/Pixstory-image-1660...
# 89771  https://image.pixstory.com/Pixstory-image-1662...
# 60284  https://image.pixstory.com/Pixstory-image-1649...
# 51552  https://image.pixstory.com/Pixstory-image-1650...
# 51434  https://image.pixstory.com/Pixstory-image-1659...
# 7041   https://image.pixstory.com/Pixstory-image-1642...
# 88466  https://image.pixstory.com/Pixstory-image-1664...
# 74241  https://image.pixstory.com/Pixstory-image-1664...
# 77674  https://image.pixstory.com/Pixstory-image-1660...
# ...

# %%
new_order = ['Dataset Index', 'Story Primary ID',
       'Story ID', 'User Primary ID', 'User ID', 'Gender', 'Age', 'Media' 'Title',
       'Narrative', 'Account Created Date', 'Date (No Timestamp)', 'Interest',
       'Narrative TikaDetect', 'Title TikaDetect', 'Narrative LangDetect',
       'Title LangDetect', 'Translated Narrative', 'Translated Title', 'GeoTopic Name', 'GeoTopic Latitude', 'GeoTopic Longitude', 'caption_generation', 'object_recognition', 'toxicity', 'severe_toxicity', 'obscene', 'identity_attack', 'insult', 'threat', 'sexual_explicit']
df = df.reindex(columns=new_order)

# %%
df.columns
# Out:
# Index(['Dataset Index', 'Story Primary ID', 'Story ID', 'User Primary ID',
#        'User ID', 'Gender', 'Age', 'MediaTitle', 'Narrative',
#        'Account Created Date', 'Date (No Timestamp)', 'Interest',
#        'Narrative TikaDetect', 'Title TikaDetect', 'Narrative LangDetect',
#        'Title LangDetect', 'Translated Narrative', 'Translated Title',
#        'GeoTopic Name', 'GeoTopic Latitude', 'GeoTopic Longitude',
#        'caption_generation', 'object_recognition', 'toxicity',
#        'severe_toxicity', 'obscene', 'identity_attack', 'insult', 'threat',
#        'sexual_explicit'],
#       dtype='object')

# %%
df.sample(20)
# Out:
#       Dataset Index Story Primary ID       Story ID User Primary ID  \
# 38409         26622            69345  STY1642162695           19480
# 4297          75079           125745  STY1660395839           72146
# 27465         13813            77032  STY1643291144            9440
# 16015           822           102738  STY1653586283              21
# 86243         83431           133614  STY1661622899           82029
# 31738         19071           122411  STY1659767098           11472
# 91438         90042           144240  STY1663318575           95402
# 94181         93329           150926  STY1664597871          105276
# 56137         72214           124179  STY1660113098           67220
# 23817          9414            77223  STY1643347212            8597
# 94367         93550           152483  STY1664987085          109351
# 13470         69220           129679  STY1660973158           58507
# 70389         64240           110327  STY1656349903           46289
# ...

# %%
df.to_csv('Master_Pixstory_EXTRACT_Dataset_Complete.tsv', sep='\t', index=False)
