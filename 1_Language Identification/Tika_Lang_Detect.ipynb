# %% [markdown]
# # Tika Language Detection

# %% [markdown]
# Make sure to start tika server in the folder where jar file is located with command: `java -jar tika-server-standard-2.6.0.jar `

# %%
from tika import language
import pandas as pd
from tqdm import tqdm

# %%
#reading in data to a df 
df = pd.read_csv('../Datasets/Master_Dataset_GoogleLangDetect.csv')
# Out:
# /var/folders/fn/pdhscw6s1wz7r1wk9ssprtz80000gn/T/ipykernel_6143/3549330898.py:2: DtypeWarning: Columns (0,2,5,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Datasets/Master_Dataset_GoogleLangDetect.csv')

# %%
#changing narrative column to type string to avoid errors while using lang detect 
df['Narrative'] = df['Narrative'].astype(str)

# %%
with tqdm(total=len(df)) as pbar:
    df['Narrative Tika Lang Detect'] = df['Narrative'].apply(lambda x: language.from_buffer(x, requestOptions={'timeout': 500}))
    pbar.update()
# Out:
#   0%|          | 0/95002 [00:18<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/fn/pdhscw6s1wz7r1wk9ssprtz80000gn/T/ipykernel_6143/5371193.py in <module>
#       1 with tqdm(total=len(df)) as pbar:
# ----> 2     df['Narrative Tika Lang Detect'] = df['Narrative'].apply(lambda x: language.from_buffer(x, requestOptions={'timeout': 500}))
#       3     pbar.update()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
# ...

# %%
df.sample(5)
# Out:
#       Story Primary ID       Story ID User Primary ID        User ID  Gender  \
# 47185         123788.0  STY1660044017         67065.0  USR1659516427     NaN
# 22164         154770.0  STY1665515483         11859.0  USR1638425715    male
# 16543         141120.0  STY1662826369         11045.0  USR1637258628  others
# 48606          97327.0  STY1651175919         28994.0  USR1647269951    male
# 42396          88291.0  STY1647711038         27909.0  USR1645083572    male
#
#         Age                                              Title  \
# 47185  28.0                         INDIAN MEDICAL ASSOCIATION
# 22164  21.0  NCERT recruitment 2022: Apply online for DTP o...
# 16543  22.0                     Brahmastra celebs movie review
# 48606  26.0  Fat Joe says the New York Knicks will win 20 m...
# 42396  24.0      Why does Ben Affleck always have wife issues?
#
#                                                Narrative  \
# 47185  IMA meeting Health Minister Sri Mansukh Mandav...
# ...

# %%
df.to_csv('../Datasets/Master_Dataset_TikaGoogleLangDetect.csv', index=False)
