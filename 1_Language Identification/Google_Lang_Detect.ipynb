# %% [markdown]
# # Google Language Detection

# %%
#importing libraries
import pandas as pd
from langdetect import detect_langs, LangDetectException

#To get consistent results, calling the following code before the first language detection
from langdetect import DetectorFactory
DetectorFactory.seed = 0

# %%
#reading in data to a df 
df = pd.read_csv('../Datasets/Master_Dataset.tsv', delimiter='\t')
# Out:
# /var/folders/fn/pdhscw6s1wz7r1wk9ssprtz80000gn/T/ipykernel_6616/2897975666.py:2: DtypeWarning: Columns (0,2,5,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Datasets/Master_Dataset.tsv', delimiter='\t')

# %%
df.head(5)
# Out:
#   Story Primary ID       Story ID User Primary ID        User ID  Gender  \
# 0         121169.0  STY1659426957           103.0  USR1606807023  female
# 1         127727.0  STY1660634861           103.0  USR1606807023  female
# 2         123665.0  STY1660027898           103.0  USR1606807023  female
# 3         130517.0  STY1661151635           103.0  USR1606807023  female
# 4         125466.0  STY1660372361           109.0  USR1606851217  others
#
#     Age                                             Title  \
# 0  34.0                     Trend of the Year: Barbiecore
# 1  34.0                            Abomination of the day
# 2  34.0                         Shameful headline in 2022
# 3  34.0  Woman lawyer arrested for abusing security guard
# 4  31.0              What is the Inflation Reduction Act?
#
#                                            Narrative  \
# 0  The colour of the year is here, and it's *drum...
# 1  We Indians do love to bastardise our foods- Ch...
# 2  Can professors not have personal lives? \n\nAd...
# 3  She was recorded on video manhandling him, sho...
# 4  The House passed the Inflation Reduction Act o...
#
#                                                Media Account Created Date  \
# 0  https://image.pixstory.com/Pixstory-image-1659...  2020-01-12 12:47:00
# 1  https://image.pixstory.com/Pixstory-image-1660...  2020-01-12 12:47:00
# 2  https://image.pixstory.com/Pixstory-image-1660...  2020-01-12 12:47:00
# 3  https://image.pixstory.com/Pixstory-image-1661...  2020-01-12 12:47:00
# 4  https://image.pixstory.com/Pixstory-image-1660...  2020-02-12 01:03:00
#
#    ... Snapchat_Closing_Stock_Price New COVID Cases New Deaths  \
# 0  ...                        17.41             0.0        0.0
# 1  ...                        17.41             0.0        0.0
# 2  ...                        17.41             0.0        0.0
# 3  ...                        17.41             0.0        0.0
# 4  ...                        17.40             0.0        0.0
#
#   New Vaccinations  YouTube Trending Video Title  \
# 0              0.0                I'm Coming Out
# 1              0.0                I'm Coming Out
# 2              0.0                I'm Coming Out
# 3              0.0                I'm Coming Out
# 4              0.0                I'm Coming Out
#
#   YouTube Trending Video Channel YouTube Trending Video Category  \
# 0                 NikkeTutorials                         Fashion
# 1                 NikkeTutorials                         Fashion
# 2                 NikkeTutorials                         Fashion
# 3                 NikkeTutorials                         Fashion
# 4                 NikkeTutorials                         Fashion
#
#   YouTube Trending Video Views YouTube Trending Video Likes  is_sarcastic
# 0                   36400000.0                    3000000.0           1.0
# 1                   36400000.0                    3000000.0           1.0
# 2                   36400000.0                    3000000.0           1.0
# 3                   36400000.0                    3000000.0           1.0
# 4                   36400000.0                    3000000.0           1.0
#
# [5 rows x 29 columns]

# %%
#changing narrative column to type string to avoid errors while using lang detect 
df['Narrative'] = df['Narrative'].astype(str)

# %%
#defining a function to detect language and handle exceptions
def detect_language(Text):

    current_index = df[df['Narrative'] == Text].index[0]
    print("Index:", current_index)

    if not Text:
        return 'n/a'
    else:
        try:
            return detect_langs(Text)
        except LangDetectException:
            return 'unknown'

# %%
# Takes 30 minutes to run on Macbook Air M1

#applying lang detect function
df['Narrative Google Lang Detect'] = df['Narrative'].apply(detect_language)

# %%
df.sample(5)
# Out:
#       Story Primary ID       Story ID User Primary ID        User ID  Gender  \
# 23339         108567.0  STY1655720489         12582.0  USR1639060058  female
# 27967         125619.0  STY1660390679         20802.0  USR1642092657    male
# 26923          96177.0  STY1650621553         19480.0  USR1641927505    male
# 51905          93339.0  STY1649778386         30355.0  USR1649153379  female
# 6207          105981.0  STY1654764052          4001.0  USR1618246144    male
#
#         Age                                              Title  \
# 23339  55.0  Scoperta in Iraq una città di 3400 anni fa, ri...
# 27967  33.0  Serie B: 2-2 nel match d’esordio tra Parma e Bari
# 26923  21.0  Planet Day: Armani lancia il sito web Armani/V...
# 51905  20.0                         Thing I hate in sandwich 🥪
# 6207   63.0                           Art Work by Rajiv Ranjan
#
#                                                Narrative  \
# 23339  Un’antica città, di ben 3.400 anni, è ritornat...
# 27967  La Serie B si apre con un bel 2-2 tra Parma e ...
# 26923  È come sempre lungimirante e pioniere, anche i...
# 51905  There are different variety of Sandwiches but ...
# 6207   The artist says he did this portrait of his re...
#
#                                                    Media Account Created Date  \
# 23339  https://image.pixstory.com/Pixstory-image-1655...  2021-12-09 19:57:38
# 27967  https://image.pixstory.com/Pixstory-image-1660...  2022-01-13 22:20:57
# 26923  https://image.pixstory.com/Pixstory-image-1650...  2022-01-12 00:28:25
# 51905  https://image.pixstory.com/Pixstory-image-1649...  2022-04-05 15:39:39
# 6207   https://image.pixstory.com/Pixstory-image-1654...  2021-04-12 22:19:04
#
#        ... New COVID Cases New Deaths New Vaccinations  \
# 23339  ...          8402.0      368.0        8369461.0
# 27967  ...        264202.0      411.0        9622002.0
# 26923  ...        247417.0      380.0        6455760.0
# 51905  ...          1086.0       71.0        1698601.0
# 6207   ...        161736.0      879.0        4004520.0
#
#                             YouTube Trending Video Title  \
# 23339                  Doja Cat - Woman (Official Video)
# 27967  OMG What is he doing? 😱 #shorts Best video by ...
# 26923  OMG What is he doing? 😱 #shorts Best video by ...
# 51905  Watch the uncensored moment Will Smith smacks ...
# 6207   I Bought The World's Largest Mystery Box! ($50...
#
#        YouTube Trending Video Channel YouTube Trending Video Category  \
# 23339                     dojacatVEVO                           Music
# 27967                        GuzNurik                   Entertainment
# 26923                        GuzNurik                   Entertainment
# 51905                   Guardian News                 News & Politics
# 6207                          MrBeast                   Entertainment
#
#       YouTube Trending Video Views YouTube Trending Video Likes is_sarcastic  \
# 23339                   21776199.0                    1680215.0          1.0
# 27967                   37273642.0                     495774.0          1.0
# 26923                   32720056.0                     448527.0          1.0
# 51905                   91958445.0                    1349433.0          1.0
# 6207                    37859804.0                    2048901.0          1.0
#
#        Narrative Google Lang Detect
# 23339       [it:0.9999969207852895]
# 27967       [it:0.9999953292463639]
# 26923       [it:0.9999975978993451]
# 51905       [en:0.9999971956920213]
# 6207        [en:0.9999981810729063]
#
# [5 rows x 30 columns]

# %%
df.to_csv('../Datasets/Master_Dataset_GoogleLangDetect.csv', index=False)
