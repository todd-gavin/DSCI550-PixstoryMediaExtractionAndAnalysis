# %%
# !pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (1.0.9)
# Requirement already satisfied: six in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from langdetect) (1.15.0)

# %%
pip install tika

# %% [markdown]
# Make sure to start tika server in the folder where jar file is located with command: `java -jar tika-server-standard-2.6.0.jar `

# %% [markdown]
# # Lang Detection -- Google

# %%
#importing libraries
import pandas as pd
from langdetect import detect_langs, LangDetectException , detect

#To get consistent results, calling the following code before the first language detection
from langdetect import DetectorFactory
DetectorFactory.seed = 0

# %%
#reading in data to a df 
df = pd.read_csv('/Users/taniadawood/Desktop/DSCI550-PixstoryMediaExtractionAndAnalysis/Datasets/Master_Dataset_Raw_LangDetect.csv')

# %%
#changing narrative column to type string to avoid errors while using lang detect 
df['Narrative'] = df['Narrative'].astype(str)
df['Title'] = df['Title'].astype(str)

# %%
#defining a function to detect language and handle exceptions
def detect_language(Text):
    if not Text:
        return 'n/a'
    else:
        try:
            return detect(Text)
        except LangDetectException:
            return 'unknown'

# %%
#applying lang detect function to narrative and title columns in dataset 
df['Narrative LangDetect'] = df['Narrative'].apply(detect_language)
df['Title LangDetect'] = df['Title'].apply(detect_language)

# %% [markdown]
# # Lang Detection -- Tika

# %%
import tika
from tika import language

# %%
#applying Tika Lang Detect to narrative and title columns in dataset 
df['Narrative TikaDetect'] = df['Narrative'].apply(lambda x: language.from_buffer(x, requestOptions={'timeout': 500}))
df['Title TikaDetect'] = df['Title'].apply(lambda x: language.from_buffer(x, requestOptions={'timeout': 500}))

# %%
df.sample(5)
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID Gender  \
# 88859            124034  STY1660067553            70256  USR1660067424    NaN
# 36168             74153  STY1642784153            23900  USR1642668922   male
# 83940            134493  STY1661787862            83114  USR1661786487    NaN
# 81692            143846  STY1663259960            78595  USR1661167460    NaN
# 52861             97308  STY1651169231            32245  USR1650287346    NaN
#
#        Age                                              Title  \
# 88859   18                                     Favourite food
# 36168   20                             # Indian ancient boobs
# 83940   18  Beutiful silver bracelet at wholesale price,me...
# 81692   21  Salman Khan's Bigg Boss gets its premiere date...
# 52861   17                                         Keep going
#
#                                                Narrative  \
# 88859                                         Random day
# 36168  1929:: Bomb Shell recovered by CID from Lahore...
# 83940  <p dir="ltr">Beutiful silver bracelet at whole...
# 81692  <p dir="ltr">Salman Khan's Bigg Boss gets its ...
# 52861  My mid week motivation revolves around the fac...
#
#                                                    Media Account Created Date  \
# 88859  https://image.pixstory.com/Pixstory-image-1660...  2022-09-08 23:20:00
# 36168  https://image.pixstory.com/Pixstory-image-1642...  2022-01-20 14:25:22
# 83940  https://image.pixstory.com/Pixstory-image-1661...  2022-08-29 20:51:27
# 81692  https://image.pixstory.com/Pixstory-image-1663...  2022-08-22 16:54:20
# 52861  https://image.pixstory.com/Pixstory-image-1651...  2022-04-18 18:39:06
#
#       Date (No Timestamp)                                           Interest  \
# 88859          2022-09-08                                           #favfood
# 36168          2022-01-20                                 ancient collection
# 83940          2022-08-29  Technology, History, Food, Entertainment, Spor...
# 81692          2022-08-22  Technology, History, Food, Entertainment, Spor...
# 52861          2022-04-18                        motivation self development
#
#       Narrative TikaDetect Title TikaDetect
# 88859                   ms               en
# 36168                   en               en
# 83940                   en               en
# 81692                   en               en
# 52861                   en               af

# %%
df.sample(5)
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID  \
# 81077            130226  STY1661091749            78005  USR1661089678
# 6143             113544  STY1657018702             4001  USR1618246144
# 88858            124037  STY1660067666            70256  USR1660067424
# 33742            100396  STY1652646386            23515  USR1642587832
# 16342            120708  STY1659344350            11045  USR1637258628
#
#        Gender  Age                                              Title  \
# 81077     NaN   19                    Sports enthusiast......NCC life
# 6143     male   63  Art event at London , Ontario from July 20 to ...
# 88858     NaN   18                                      Polaroid love
# 33742     NaN   23  Maxi-schermi al Bernabeu: l’iniziativa del Rea...
# 16342  others   22        Nushrratt Bharuccha to shoot for Chhori 2👧❌
#
#                                                Narrative  \
# 81077   <p dir="ltr">Sports enthusiast......NCC life</p>
# 6143   Sharmistha Kar and Gabriella Solti, London-bas...
# 88858                                                 ❤️
# 33742  Il Real Madrid ha reso noto che verranno inser...
# 16342  The story of Chhorii will continue from part o...
#
#                                                    Media Account Created Date  \
# 81077  https://image.pixstory.com/Pixstory-image-1661...  2022-08-21 19:17:58
# 6143   https://image.pixstory.com/Pixstory-image-1657...  2021-04-12 22:19:04
# 88858  https://image.pixstory.com/Pixstory-image-1660...  2022-09-08 23:20:00
# 33742  https://image.pixstory.com/Pixstory-image-1652...  2022-01-19 15:53:52
# 16342  https://image.pixstory.com/Pixstory-image-1659...  2021-11-18 23:33:48
#
#       Date (No Timestamp)                                           Interest  \
# 81077          2022-08-21  Technology, History, Food, Entertainment, Envi...
# 6143           2021-04-12  art, london , ontario, sharmistha kar, good sp...
# 88858          2022-09-08                                         #polaroids
# 33742          2022-01-19                                        real madrid
# 16342          2021-11-18  bollywood music, bollywood fashion, bollywood,...
#
#       Narrative TikaDetect Title TikaDetect Narrative LangDetect  \
# 81077                   en               en                   en
# 6143                    en               en                   en
# 88858                                    sl              unknown
# 33742                   it               it                   it
# 16342                   en               en                   en
#
#       Title LangDetect
# 81077               en
# 6143                en
# 88858               sl
# 33742               it
# 16342               en

# %%
df.to_csv('Master_Dataset_Raw_LangDetect_Complete.csv', index=False)
