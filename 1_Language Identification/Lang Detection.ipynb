# %%
#installing langdetect
# !pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (1.0.9)
# Requirement already satisfied: six in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from langdetect) (1.15.0)

# %%
pip install mtdata
# Out:
# Requirement already satisfied: mtdata in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (0.3.8)
# Requirement already satisfied: requests==2.26.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from mtdata) (2.26.0)
# Requirement already satisfied: pybtex==0.24.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from mtdata) (0.24.0)
# Requirement already satisfied: portalocker==2.3.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from mtdata) (2.3.0)
# Requirement already satisfied: ruamel.yaml>=0.17.10 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from mtdata) (0.17.21)
# Requirement already satisfied: enlighten==1.10.1 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from mtdata) (1.10.1)
# Requirement already satisfied: prefixed>=0.3.2 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from enlighten==1.10.1->mtdata) (0.7.0)
# Requirement already satisfied: blessed>=1.17.7 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from enlighten==1.10.1->mtdata) (1.20.0)
# Requirement already satisfied: PyYAML>=3.01 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from pybtex==0.24.0->mtdata) (5.4.1)
# Requirement already satisfied: latexcodec>=1.0.4 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from pybtex==0.24.0->mtdata) (2.0.1)
# Requirement already satisfied: six in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from pybtex==0.24.0->mtdata) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests==2.26.0->mtdata) (1.26.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests==2.26.0->mtdata) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests==2.26.0->mtdata) (2020.12.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests==2.26.0->mtdata) (2.10)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from blessed>=1.17.7->enlighten==1.10.1->mtdata) (0.2.5)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from ruamel.yaml>=0.17.10->mtdata) (0.2.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install nlcodec
# Out:
# Collecting nlcodec
#   Downloading nlcodec-0.5-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 616 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from nlcodec) (1.20.1)
# Requirement already satisfied: tqdm in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from nlcodec) (4.59.0)
# Installing collected packages: nlcodec
# Successfully installed nlcodec-0.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rtg
# Out:
# Collecting rtg
#   Downloading rtg-0.7.2-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 915 kB/s eta 0:00:01
# Collecting sacrebleu-macrof==2.0.1
#   Downloading sacrebleu_macrof-2.0.1-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 3.2 MB/s eta 0:00:01
# Collecting torch>=1.10
#   Downloading torch-2.0.0-cp38-none-macosx_10_9_x86_64.whl (139.5 MB)
#      |████████████████████████████████| 139.5 MB 42 kB/s  eta 0:00:01    |████▊                           | 20.4 MB 1.7 MB/s eta 0:01:10
# Requirement already satisfied: ruamel.yaml>=0.17.10 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from rtg) (0.17.21)
# Requirement already satisfied: nlcodec>=0.5 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from rtg) (0.5)
# Collecting tensorboard>=2.6.0
#   Downloading tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 8.7 MB/s eta 0:00:01
# Collecting sentencepiece>=0.1.85
#   Downloading sentencepiece-0.1.97-cp38-cp38-macosx_10_9_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 1.6 MB/s eta 0:00:01
# Collecting torchtext>=0.10.0
#   Downloading torchtext-0.15.1-cp38-cp38-macosx_10_9_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 11.1 MB/s eta 0:00:01
# Requirement already satisfied: tqdm>=4.45.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from rtg) (4.59.0)
# Requirement already satisfied: portalocker>=2.0.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from rtg) (2.3.0)
# Collecting sacremoses>=0.0.45
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 7.5 MB/s eta 0:00:01
# Requirement already satisfied: pyspark>=3.0.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from rtg) (3.3.0)
# Requirement already satisfied: colorama in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from sacrebleu-macrof==2.0.1->rtg) (0.4.4)
# Collecting tabulate>=0.8.9
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: regex in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from sacrebleu-macrof==2.0.1->rtg) (2021.4.4)
# Requirement already satisfied: numpy>=1.17 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from sacrebleu-macrof==2.0.1->rtg) (1.20.1)
# Requirement already satisfied: py4j==0.10.9.5 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from pyspark>=3.0.0->rtg) (0.10.9.5)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from ruamel.yaml>=0.17.10->rtg) (0.2.7)
# Requirement already satisfied: six in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from sacremoses>=0.0.45->rtg) (1.15.0)
# Requirement already satisfied: click in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from sacremoses>=0.0.45->rtg) (7.1.2)
# Requirement already satisfied: joblib in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from sacremoses>=0.0.45->rtg) (1.0.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
#      |████████████████████████████████| 4.8 MB 4.8 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from tensorboard>=2.6.0->rtg) (2.26.0)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 8.1 MB/s eta 0:00:01
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 2.4 MB/s eta 0:00:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.2-py2.py3-none-any.whl (177 kB)
#      |████████████████████████████████| 177 kB 1.1 MB/s eta 0:00:01
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from tensorboard>=2.6.0->rtg) (1.0.1)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.2-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 6.3 MB/s  eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting protobuf>=3.19.6
#   Downloading protobuf-4.22.1-cp37-abi3-macosx_10_9_universal2.whl (397 kB)
#      |████████████████████████████████| 397 kB 740 kB/s eta 0:00:01
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.51.3-cp38-cp38-macosx_10_10_universal2.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 16.2 MB/s eta 0:00:01
# Requirement already satisfied: wheel>=0.26 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from tensorboard>=2.6.0->rtg) (0.36.2)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from tensorboard>=2.6.0->rtg) (52.0.0.post20210125)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 1.8 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-6.1.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.6.0->rtg) (3.4.1)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 673 kB/s eta 0:00:01
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.6.0->rtg) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.6.0->rtg) (2020.12.5)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.6.0->rtg) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard>=2.6.0->rtg) (2.10)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 12.2 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.10->rtg) (3.7.4.3)
# Requirement already satisfied: jinja2 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.10->rtg) (2.11.3)
# Requirement already satisfied: sympy in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.10->rtg) (1.8)
# Requirement already satisfied: filelock in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.10->rtg) (3.0.12)
# Requirement already satisfied: networkx in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.10->rtg) (2.5)
# Collecting torchdata==0.6.0
#   Downloading torchdata-0.6.0-cp38-cp38-macosx_10_13_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 11.3 MB/s eta 0:00:01
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from jinja2->torch>=1.10->rtg) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from networkx->torch>=1.10->rtg) (5.0.6)
# Requirement already satisfied: mpmath>=0.19 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from sympy->torch>=1.10->rtg) (1.2.1)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895254 sha256=21161f320ff21f50993e1bbb56ec9038022bd9b2a14c410986163ac0042888c8
#   Stored in directory: /Users/taniadawood/Library/Caches/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# Installing collected packages: pyasn1, rsa, pyasn1-modules, oauthlib, cachetools, torch, requests-oauthlib, importlib-metadata, google-auth, torchdata, tensorboard-plugin-wit, tensorboard-data-server, tabulate, protobuf, markdown, grpcio, google-auth-oauthlib, absl-py, torchtext, tensorboard, sentencepiece, sacremoses, sacrebleu-macrof, rtg
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 3.10.0
#     Uninstalling importlib-metadata-3.10.0:
#       Successfully uninstalled importlib-metadata-3.10.0
# Successfully installed absl-py-1.4.0 cachetools-5.3.0 google-auth-2.16.2 google-auth-oauthlib-0.4.6 grpcio-1.51.3 importlib-metadata-6.1.0 markdown-3.4.2 oauthlib-3.2.2 protobuf-4.22.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 rtg-0.7.2 sacrebleu-macrof-2.0.1 sacremoses-0.0.53 sentencepiece-0.1.97 tabulate-0.9.0 tensorboard-2.12.0 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1 torch-2.0.0 torchdata-0.6.0 torchtext-0.15.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Lang Detection - Google

# %%
#importing libraries
import pandas as pd
from langdetect import detect_langs, LangDetectException

#To get consistent results, calling the following code before the first language detection
from langdetect import DetectorFactory
DetectorFactory.seed = 0

# %%
#reading in data to a df 
df = pd.read_csv('/Users/taniadawood/Desktop/DSCI550-PixstoryMediaExtractionAndAnalysis/Datasets/Master_Dataset_Raw_LangDetect.csv')

# %%
df.head(1)
# Out:
#    Story Primary ID       Story ID  User Primary ID        User ID  Gender  \
# 0            121169  STY1659426957              103  USR1606807023  female
#
#    Age                          Title  \
# 0   34  Trend of the Year: Barbiecore
#
#                                            Narrative  \
# 0  The colour of the year is here, and it's *drum...
#
#                                                Media Account Created Date  \
# 0  https://image.pixstory.com/Pixstory-image-1659...  2020-01-12 12:47:00
#
#   Date (No Timestamp)                 Interest
# 0          2020-01-12  trends, fashion, barbie

# %%
#changing narrative column to type string to avoid errors while using lang detect 
df['Narrative'] = df['Narrative'].astype(str)

# %%
#defining a function to detect language and handle exceptions
def detect_language(Text):
    if not Text:
        return 'n/a'
    else:
        try:
            return detect_langs(Text)
        except LangDetectException:
            return 'unknown'

# %%
#applying lang detect function
df['Narrative LangDetect'] = df['Narrative'].apply(detect_language)

# %%
df.sample(20)
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID  \
# 7768              96704  STY1650875309             7404  USR1625141229
# 85173            147150  STY1663780881            84859  USR1662040033
# 76681            126839  STY1660502176            73481  USR1660498694
# 11640             85392  STY1646497862             9221  USR1632727815
# 79649            129438  STY1660909412            76865  USR1660909343
# 31965             71710  STY1642440054            22972  USR1642439946
# 2229             100129  STY1652511331              370  USR1610710717
# 68880            149860  STY1664301342            57711  USR1657793493
# 54741            156443  STY1666082963            32675  USR1650434732
# 21421            117571  STY1658325360            11859  USR1638425715
# 56945            100064  STY1652474309            33780  USR1650904199
# 65258            111510  STY1656672591            51312  USR1656672265
# 47784            133220  STY1661578412            28833  USR1646828149
# 8419              88730  STY1647883598             8095  USR1627371213
# 3357             122305  STY1659718130            11859  USR1638425715
# 8696             126514  STY1660484159             1865  USR1615199963
# 72595            140719  STY1662785652            68795  USR1659851929
# 31230             91692  STY1649000435            22890  USR1642432836
# 3715             153099  STY1665129817              632  USR1613386215
# 86486            137183  STY1662288834            86499  USR1662287592
#
#        Gender  Age                                              Title  \
# 7768     male   22                         John Wick 4 Poster reveal!
# 85173     NaN   23  England join fellow UEFA nations for OneLove C...
# 76681     NaN   19                                         Sweet home
# 11640    male   23  The #1 Best Eating Habit to Slow Aging, Says D...
# 79649     NaN   19                                         Go karting
# 31965     NaN   27                                        Virat kohli
# 2229     male   46  Congress' chintan: One family, one ticket rule...
# 68880  female   38  Everybody is laughing: Manchester United legen...
# 54741     NaN   21  Three arguments why Just Stop Oil was right to...
# 21421    male   21  কমনওয়েলথ গেমস-এ ২০০ মিটার ইভেন্টে যোগ্যতা অর্...
# 56945     NaN   22     Shortage of Baby Formula; New Crisis for Women
# 65258     NaN   22                                            Rainbow
# 47784  others   12  How Bengal politics is dependent on syndicate ...
# 8419     male   26  Russia-Ukraine War: Has the war helped in stab...
# 3357     male   21  বাবার হত্যাকারীরা আমাকেও সরিয়ে দিতে চায়: বাংলা...
# 8696     male   54                                  Event Inspiration
# 72595     NaN   24                       ശ്രീ നാരായണ ഗുരു ജയന്തി ദിനം
# 31230     NaN   21              I fossili: quelli veri e quelli falsi
# 3715   others   12  News Flash: Dentsu Creative India elevates Ben...
# 86486     NaN   18                         nothing but blue skies! 👀💙
#
#                                                Narrative  \
# 7768   First promotional movie poster for John Wick C...
# 85173  <p dir="ltr">England have officially announced...
# 76681  Beautiful clouds . Nature is good. Live life. ...
# 11640  Foods do really have an impact on our aging pr...
# 79649                                 Burnout go karting
# 31965                                        Bye captain
# 2229   The Congress seems to have carefully drafted i...
# 68880  <p dir="ltr">Everybody is laughing: Manchester...
# 54741  <p dir="ltr">Waves of controversy were sparked...
# 21421  https://bengali.nenow.in/sports/hima-das-quali...
# 56945  Recent chaos is about the unavailability of ba...
# 65258                         Beautiful click of rainbow
# 47784  <p dir="ltr">By Sayantan Ghosh</p>\n<p dir="lt...
# 8419   After remaining in a deep freeze for more than...
# 3357   ১৯৭৫ সালের ‘১৫ আগস্ট আমার বাবার ঘাতকরা এখনো তৎ...
# 8696   Events are a great way to create content for y...
# 72595  <p dir="ltr">'&#3381;&#3391;&#3366;&#3405;&#33...
# 31230  I fossili sono i resti o le tracce di animali ...
# 3715   <p dir="ltr"><b>By BestMediaInfo Bureau </p><p...
# 86486  <p dir="ltr">nothing but blue skies! &#128064;...
#
#                                                    Media Account Created Date  \
# 7768   https://image.pixstory.com/Pixstory-image-1650...  2021-07-01 17:37:09
# 85173  https://image.pixstory.com/Pixstory-image-1663...  2022-09-01 19:17:13
# 76681  https://image.pixstory.com/Pixstory-image-1660...  2022-08-14 23:08:14
# 11640  https://image.pixstory.com/Pixstory-image-1646...  2021-09-27 13:00:15
# 79649  https://image.pixstory.com/Pixstory-image-1660...  2022-08-19 17:12:00
# 31965  https://image.pixstory.com/Pixstory-image-1642...  2022-01-17 22:49:06
# 2229   https://image.pixstory.com/Pixstory-image-1652...  2021-01-15 17:08:37
# 68880  https://image.pixstory.com/Pixstory-image-1664...  2022-07-14 15:41:33
# 54741  https://image.pixstory.com/Pixstory-image-1666...  2022-04-20 11:35:32
# 21421  https://image.pixstory.com/Pixstory-image-1658...  2021-12-02 11:45:15
# 56945  https://image.pixstory.com/Pixstory-image-1652...  2022-04-25 21:59:59
# 65258  https://image.pixstory.com/Pixstory-image-1656...  2022-07-01 16:14:25
# 47784  https://image.pixstory.com/Pixstory-image-1661...  2022-03-09 17:45:49
# 8419   https://image.pixstory.com/Pixstory-image-1647...  2021-07-27 13:03:33
# 3357   https://image.pixstory.com/Pixstory-image-1659...  2021-02-12 11:45:00
# 8696   https://image.pixstory.com/Pixstory-image-1660...  2021-08-03 16:09:00
# 72595  https://image.pixstory.com/Pixstory-image-1662...  2022-08-07 11:28:49
# 31230  https://image.pixstory.com/Pixstory-image-1649...  2022-01-17 20:50:36
# 3715   https://image.pixstory.com/Pixstory-image-1665...  2021-02-15 16:20:15
# 86486  https://image.pixstory.com/Pixstory-image-1662...  2022-09-04 16:03:12
#
#       Date (No Timestamp)                                           Interest  \
# 7768           2021-07-01                           hollywood, Entertainment
# 85173          2022-09-01           england, uefa, football, worldcup, qatar
# 76681          2022-08-14                                           football
# 11640          2021-09-27                                 mediterranean diet
# 79649          2022-08-19                                          gokarting
# 31965          2022-01-17                       comspectlbc, Sports, cricket
# 2229           2021-01-15                 Politics, congress, chintan shivir
# 68880          2022-07-14  Technology, History, Food, Entertainment, Spor...
# 54741          2022-04-20  Technology, History, Food, Entertainment, Spor...
# 21421          2021-12-02  hima das qualifies for commonwealth games, bir...
# 56945          2022-04-25                      baby formula shortage, crisis
# 65258          2022-07-01                                                sky
# 47784          2022-03-09  Technology, History, Food, Entertainment, Spor...
# 8419           2021-07-27  ukraine war, india china standoff, united stat...
# 3357           2021-02-12                                         bangladesh
# 8696           2021-08-03  content marketing, content creator, events, ev...
# 72595          2022-08-07  #jai guru dev, #equality and human rights, # o...
# 31230          2022-01-17                     fossili, storia, paleontologia
# 3715           2021-02-15  Technology, History, Food, Entertainment, Spor...
# 86486          2022-09-04  Technology, History, Food, Entertainment, Spor...
#
#                                     Narrative LangDetect
# 7768                             [en:0.9999973365080322]
# 85173                            [en:0.9999963187017668]
# 76681    [en:0.8571413607135834, fr:0.14285815370074392]
# 11640                            [en:0.9999973444325871]
# 79649     [tl:0.7142825738496784, hr:0.2857135116031992]
# 31965  [fr:0.5714273555512095, ro:0.2857136767499527,...
# 2229                             [en:0.9999985244433706]
# 68880                            [en:0.9999936711598159]
# 54741                            [en:0.9999945887455157]
# 21421                            [bn:0.9999999920328431]
# 56945                            [en:0.9999977770771279]
# 65258                            [en:0.9999955055829294]
# 47784                            [en:0.9999976757378946]
# 8419                              [en:0.999998313151761]
# 3357                              [bn:0.999999998620089]
# 8696                             [en:0.9999950248497852]
# 72595    [no:0.5710356646555665, cy:0.42890100210782983]
# 31230                            [it:0.9999973733413957]
# 3715                             [en:0.9999987979221155]
# 86486     [af:0.5714265409152949, en:0.4285725624484401]

# %% [markdown]
# Lang Detection - Tika

# %%
pip install tika
# Out:
# Requirement already satisfied: tika in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (2.6.0)
# Requirement already satisfied: setuptools in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from tika) (52.0.0.post20210125)
# Requirement already satisfied: requests in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from tika) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests->tika) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests->tika) (1.26.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests->tika) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests->tika) (2.0.12)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade tika
# Out:
# Requirement already satisfied: tika in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (2.6.0)
# Requirement already satisfied: requests in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from tika) (2.26.0)
# Requirement already satisfied: setuptools in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from tika) (52.0.0.post20210125)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests->tika) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests->tika) (2020.12.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests->tika) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/taniadawood/opt/anaconda3/lib/python3.8/site-packages (from requests->tika) (2.0.12)

# %%
from tika import language

# %%
df['Narrative TikaDetect'] = df['Narrative'].apply(lambda x: language.from_buffer(x))

# %%
df.sample(20)
# Out:
#        Story Primary ID       Story ID  User Primary ID        User ID  \
# 18943            101397  STY1653037109            11460  USR1637921462
# 35105            114912  STY1657446800            23728  USR1642615528
# 37701             75474  STY1643020982            25289  USR1643020254
# 51408             90305  STY1648414252            29630  USR1648414099
# 28528             69545  STY1642170980            21364  USR1642169492
# 83264            133318  STY1661591537            81602  USR1661587097
# 5138             135451  STY1661935623             1865  USR1615199963
# 20260             75518  STY1643025968            11835  USR1638362514
# 41714            112005  STY1656725640            27359  USR1644690935
# 61330            103722  STY1653986329            39733  USR1653650941
# 7926             102448  STY1653471345             7404  USR1625141229
# 61571            123198  STY1659916884            40917  USR1654101217
# 12216            137472  STY1662315238             9256  USR1632837537
# 78712            147016  STY1663765793            75741  USR1660757478
# 65960            112617  STY1656836644            52566  USR1656836532
# 73155            123411  STY1659965536            69508  USR1659965456
# 50185             89652  STY1648185499            29028  USR1647404855
# 48648            113767  STY1657062362            28994  USR1647269951
# 44977             92155  STY1649222964            28653  USR1646144495
# 50348            114494  STY1657276047            29049  USR1647426127
#
#        Gender  Age                                              Title  \
# 18943    male   36  In caso di scudetto il Milan festeggerà lunedì...
# 35105     NaN   63  Pogba ha in testa solo la Juve: no all'autogra...
# 37701     NaN   18                              Fact about house cats
# 51408     NaN   22                              Passion with hardwork
# 28528     NaN   20                               Louvre Museum, Paris
# 83264     NaN   20                                            #Nature
# 5138     male   54  Event Inspiration\n\nAs an event professional,...
# 20260    male   12  কোভিড হটস্পটত পৰিণত সংসদ ভৱন, সহস্ৰাধিক কৰ্মচা...
# 41714  female   12  A ‘bull crap’ coaching manual plaguing Austral...
# 61330    male   39      2. Decoding Indian Babudom - Data 'mis-entry'
# 7926     male   22       The Gray Man Trailer is out and its amazing.
# 61571    male   23                 Kevin Owens may soon be back on TV
# 12216  female   20  It's been a long semester ....\nJust need a va...
# 78712     NaN   21                 Everyone operates differently... 🫰
# 65960     NaN   21                                                Hii
# 73155     NaN   20                                              Arpan
# 50185  female   20  Oil-free food, no milk, daily yoga: Padma Shri...
# 48648    male   26        The Dunk by John Starks! The iconic moment!
# 44977    male   30  5 possible deciding factors ahead of tonight's...
# 50348    male   12        8. Diary of a Cop : Bridge of spies amid us
#
#                                                Narrative  \
# 18943  Quello che sta per cominciare sarà un fine set...
# 35105  Il Manchester United ormai fa parte del suo pa...
# 37701  A house cat’s genome is 95.6 percent tiger, an...
# 51408           🔥Following dreams with lots of hardwork🔥
# 28528         Take me here and I'm your's.\n#enactusshiv
# 83264                           <p dir="ltr">#Nature</p>
# 5138   <p dir="ltr">Event Inspiration</p>\n<p dir="lt...
# 20260  বাজেট অধিৱেশনলৈ মাজত মাত্ৰ কেইটামান দিন। এনে স...
# 41714  As Australia advanced in their match against S...
# 61330  Decoding Indian Babudom - Data ‘mis-entry’ con...
# 7926   Netflix has finally released the trailer for "...
# 61571  There are backstage updates about a few WWE Su...
# 12216  <p dir="ltr">It's been a long semester ....<br...
# 78712  <p dir="ltr">Everyone operates differently... ...
# 65960                                               Hiii
# 73155                         Hey everyone this is Arpan
# 50185  Swami Sivananda, who was born in Sylhet distri...
# 48648  The Dunk. Something so iconic that a fan even ...
# 44977  Stamford Bridge hosts one of the most awaited ...
# 50348  Of the constant flurry of visitors reaching ro...
#
#                                                    Media Account Created Date  \
# 18943  https://image.pixstory.com/Pixstory-image-1653...  2021-11-26 15:41:02
# 35105  https://image.pixstory.com/Pixstory-image-1657...  2022-01-19 23:35:28
# 37701  https://image.pixstory.com/Pixstory-image-1643...  2022-01-24 16:00:54
# 51408  https://image.pixstory.com/Pixstory-image-1648...  2022-03-28 02:18:19
# 28528  https://image.pixstory.com/Pixstory-image-1642...  2022-01-14 19:41:32
# 83264  https://image.pixstory.com/Pixstory-image-1661...  2022-08-27 13:28:17
# 5138   https://image.pixstory.com/Pixstory-image-1661...  2021-03-08 16:09:23
# 20260  https://image.pixstory.com/Pixstory-image-1643...  2021-12-01 18:11:54
# 41714  https://image.pixstory.com/Pixstory-image-1656...  2022-02-13 00:05:35
# 61330  https://image.pixstory.com/Pixstory-image-1653...  2022-05-27 16:59:01
# 7926   https://image.pixstory.com/Pixstory-image-1653...  2021-07-01 17:37:09
# 61571  https://image.pixstory.com/Pixstory-image-1659...  2022-06-01 22:03:37
# 12216  https://image.pixstory.com/Pixstory-image-1662...  2021-09-28 19:28:57
# 78712  https://image.pixstory.com/Pixstory-image-1663...  2022-08-17 23:01:18
# 65960  https://image.pixstory.com/Pixstory-image-1656...  2022-07-03 13:52:12
# 73155  https://image.pixstory.com/Pixstory-image-1659...  2022-08-08 19:00:56
# 50185  https://image.pixstory.com/Pixstory-image-1648...  2022-03-16 09:57:35
# 48648  https://image.pixstory.com/Pixstory-image-1657...  2022-03-14 20:29:11
# 44977  https://image.pixstory.com/Pixstory-image-1649...  2022-03-01 19:51:35
# 50348  https://image.pixstory.com/Pixstory-image-1657...  2022-03-16 15:52:07
#
#       Date (No Timestamp)                                           Interest  \
# 18943          2021-11-26                              milan, inter, serie a
# 35105          2022-01-19                 pogba, juventus, manchester united
# 37701          2022-01-24                                  cats, pets, facts
# 51408          2022-03-28                                       wow womaniya
# 28528          2022-01-14                                      museums, moon
# 83264          2022-08-27  Technology, History, Food, Entertainment, Spor...
# 5138           2021-03-08  events, event marketing, event profs, shareyaa...
# 20260          2021-12-01                                           covid 19
# 41714          2022-02-13                                             Sports
# 61330          2022-05-27                            decoding indian babudom
# 7926           2021-07-01    hollywood, Entertainment, netflix, ryan gosling
# 61571          2022-06-01                                                wwe
# 12216          2021-09-28  Technology, History, Food, Entertainment, Spor...
# 78712          2022-08-17  Technology, History, Food, Entertainment, Spor...
# 65960          2022-07-03                                                hii
# 73155          2022-08-08                                              music
# 50185          2022-03-16                  padma shri, swami sivananda, yoga
# 48648          2022-03-14                      knicks, the dunk, john starks
# 44977          2022-03-01  stamford bridge, real madrid, midfield, chelse...
# 50348          2022-03-16                      diary of a cop, vikas vaibhav
#
#           Narrative LangDetect Narrative TikaDetect
# 18943  [it:0.9999981641799927]                   it
# 35105  [it:0.9999959380049301]                   it
# 37701   [en:0.999998055662397]                   en
# 51408   [en:0.999998441698126]                   en
# 28528  [en:0.9999966087855112]                   en
# 83264  [ro:0.9999931698291242]                   ro
# 5138   [en:0.9999986218093218]                   en
# 20260   [bn:0.999999997501455]                   bn
# 41714  [en:0.9999963690787056]                   en
# 61330  [en:0.9999951348646607]                   en
# 7926   [en:0.9999968646893349]                   en
# 61571  [en:0.9999983477464238]                   en
# 12216  [en:0.9999950372583379]                   en
# 78712  [en:0.9999969230559402]                   en
# 65960  [et:0.9999920076492226]                   so
# 73155  [en:0.9999968127034595]                   en
# 50185  [en:0.9999944582024946]                   en
# 48648  [en:0.9999975930402274]                   en
# 44977  [en:0.9999940261190522]                   en
# 50348  [en:0.9999971950173849]                   en
